# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Data
data = {
    "% reduction": [0.1, 0.2, 0.25, 0.4, 0.5, 0.6, 0.7, 0.8, 0.9],
    "Random": [0.77165087382419, 0.762660058738327, 0.764975288717151, 0.758367128440467, 0.760235257363314,
               0.755084315292654, 0.741786316999443, 0.725153936490737, 0.692792269293777],
    "Bcos": [0.77304399626581, 0.762013018795831, 0.75465418023242, 0.762863034650456, 0.746470118001443,
             0.754102237169045, 0.733869081686715, 0.705280223009265, 0.674175619227681],
    "Instance_deletion": [0.769730931339079, 0.770741880698579, 0.764134060589126, 0.764667235689158, 0.748413884311235,
              0.733197635332833, 0.726564066355401, 0.715485107134568, 0.668755950409522],
    "SVC": [0.771275632014756, 0.775584389446687, 0.76430780089312, 0.759465911510931, 0.754297099272021,
            0.742884196000814, 0.752065109215193, 0.72546886513108, 0.696859067779371]
}

df = pd.DataFrame(data)
df_melted = df.melt(id_vars="% reduction", var_name="Method", value_name="F1 Score")

# Plot
plt.figure(figsize=(10, 6))
sns.lineplot(data=df_melted, x="% reduction", y="F1 Score", hue="Method", marker="o")
plt.title("F1 score with different reduction sizes across methods \n Vader Dataset")
plt.xlabel("% Reduction")
plt.ylabel("F1 Score")
plt.grid(True)
plt.legend(title="Method")
plt.tight_layout()
plt.show()
